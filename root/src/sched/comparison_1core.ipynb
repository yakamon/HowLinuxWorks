# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
d1 = pd.read_csv('./1core-1process.csv')
d2 = pd.read_csv('./1core-2process.csv')
d3 = pd.read_csv('./1core-3process.csv')

# %%
d1.plot.scatter(x = 'since_start', y = 'id', ylim=(0, 3))

# %%
d2.plot.scatter(x = 'since_start', y = 'id', ylim=(0, 3))

# %%
d3.plot.scatter(x = 'since_start', y = 'id', ylim=(0, 3))

# %%
d1.plot.scatter(x = 'since_start', y = 'progress')

# %%
d2.plot.scatter(x = 'since_start', y = 'progress', c = 'id', colormap='viridis')

# %%
d3.plot.scatter(x = 'since_start', y = 'progress', c = 'id', colormap='viridis')
