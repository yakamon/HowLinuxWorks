# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
d1 = pd.read_csv('2core_1process.csv')
d2 = pd.read_csv('2core_2process.csv')
d4 = pd.read_csv('2core_4process.csv')

# %%
d1.plot.scatter(x = 'since_start', y = 'id', ylim=(0, 3))

# %%
d1.plot.scatter(x = 'since_start', y = 'progress', c = 'id', colormap='viridis')

# %%
d2.plot.scatter(x = 'since_start', y = 'id', ylim=(0, 3))

# %%
d2.plot.scatter(x = 'since_start', y = 'progress', c = 'id', colormap='viridis')

# %%
d4.plot.scatter(x = 'since_start', y = 'id', ylim=(0, 3))

# %%
d4.plot.scatter(x = 'since_start', y = 'progress', c = 'id', colormap='viridis')
