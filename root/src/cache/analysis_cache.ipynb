# %%
import pandas as pd
import numpy as np

# %%
d = pd.read_csv("output_cache.log")

# %%
d["log_access_time"] = np.log(d["access_time"])

# %%
d.plot.scatter(x="size", y="access_time")

# %%
d.plot.scatter(x="size_exp", y="log_access_time")
